# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **santhi sampath**
#
#    Data scientist

# %% [markdown]
# *I am interested in data science because i love to work with data*

# %% [markdown]
# <h3>here i want to show few arithmetic operatons and also print my favorite number<h3>

# %%
# add,multi,division,sub
print(5+3)
print(2*4)
print(8/1)
print(9-1)
# fave number 
FAVORITE_NUMBER = 4
print(FAVORITE_NUMBER)
# Out:
# 8
# 8
# 8.0
# 8
# 4

# %% [markdown]
# >i am inevitable
# <ol>
# <li>cheese burger</li>
# <li>club sandwich</li>
# <li>pepperoni pizza</li>
# </ol>!
# ![Bae%20Suzy%20Net%20Worth.jpg](attachment:Bae%20Suzy%20Net%20Worth.jpg)
#
#
# ----------------------------------------------
# ------------------------------------------
# ------------------------
# -------------
